# %%
import sddk

# %%
# optional: login to sciencedata; not necessary for read-only mode
# conf = sddk.configure("SDAM_root", "648597@au.dk")

# %%
public_file_code = "da20ee5baa8c323a6e073bc8bd9c4988"
EDH_cleaned = sddk.read_file("https://sciencedata.dk/public/" + public_file_code, "df")
# Out:
# reading a publicly shared file

# %%
# look at first five rows
EDH_cleaned.head(5)
# Out:
#   responsible_individual      type_of_inscription letter_size not_after  \
# 0              [Feraudi]                [epitaph]  [3.2-2 cm]    [0130]
# 1              [Feraudi]                [epitaph]      [4 cm]    [0200]
# 2              [Feraudi]  [honorific inscription]  [4.5-3 cm]    [0170]
# 3                 [Gräf]     [votive inscription]    [2.5 cm]    [0200]
# 4              [Feraudi]                [epitaph]          {}    [0200]
#
#                                           literature           work_status  \
# 0  [AE 1983, 0192.; M. Annecchino, Puteoli 4/5, 1...         [provisional]
# 1  [AE 1983, 0080. (A); A. Ferrua, RAL 36, 1981, ...            [no image]
# 2  [AE 1983, 0518. (B); J. González, ZPE 52, 1983...         [provisional]
# 3  [AE 1983, 0533. (B); A.U. Stylow, Gerión 1, 19...  [checked with photo]
# 4  [AE 1983, 0078. (B); A. Ferrua, RAL 36, 1981, ...            [no image]
#
#       height                                    diplomatic_text  \
# ...

# %%
EDH_cleaned
