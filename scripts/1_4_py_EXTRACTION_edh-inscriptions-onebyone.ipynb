# %% [markdown]
# # INTRODUCTION
#
# This notebook explores the potential of the Epigraphic Database Heidelberg web API , [EDH API](https://edh-www.adw.uni-heidelberg.de/data/api) in combination with sciencedata.dk as a datastorage (see more about our current progress in using sciencedata.dk [here](https://docs.google.com/document/d/1sojHsxkcAbZH9DpWFuHDomQwTZHPQv_WaAxO_erP6FE/edit?usp=sharing)).
#
# The ambition here is to use cloud based solutions as much as possible, without any dependence on local machines. At the same time, we do not like to rely completely upon google services.

# %%
### REQUIREMENTS
import numpy as np
import math
import pandas as pd

import sys
### we do a lot of requests during the scrapping. Some of them with requests package, some of them with urllib
import requests
from urllib.request import urlopen 
from urllib.parse import quote  
from bs4 import BeautifulSoup
import xml.etree.cElementTree as ET

# to avoid errors, we sometime use time.sleep(N) before retrying a request
import time
# the input data have typically a json structure
import json
import getpass

import datetime as dt
# for simple paralel computing:
from concurrent.futures import ThreadPoolExecutor
### google drive
from google.colab import drive
#import gspread
#from gspread_dataframe import get_as_dataframe, set_with_dataframe

# !pip install --ignore-installed --index-url https://test.pypi.org/simple/ --no-deps sddk ### our own package under construction, always install to have up-to-date version
import sddk
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting sddk
#   Using cached https://test-files.pythonhosted.org/packages/65/8b/d682c15a7335215ac119538ad8455b408cd7e8be4f6614678888dd2c88ed/sddk-0.0.7-py3-none-any.whl
# Installing collected packages: sddk
# Successfully installed sddk-0.0.7

# %% [markdown]
# ## configure session and url

# %%
### configure session and url
### in the case of "SDAM_root", the group owner is Vojtech with username 648597@au.dk
s, sddk_url = sddk.configure_session_and_url("SDAM_root")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ··········
# personal connection established
# group connection established with you as owner
# endpoint for requests has been configured to: https://sciencedata.dk/files/SDAM_root/

# %% [markdown]
# # EDH via API

# %% [markdown]
# The basis form of an request is as follows:
# ```
# https://edh-www.adw.uni-heidelberg.de/data/api/inscriptions/search?
# ```
# With this, to create query based on inscription number, you will have tospecify the paramenter **hd_nr**, like here:
#
# ```
# https://edh-www.adw.uni-heidelberg.de/data/api/inscriptions/search?hd_nr=1
# ```
#  (Feel free to explore this in the browser).
#
# Here we use the function ```requests.get()``` to make our requests from python.

# %% [markdown]
# ## One inscription query example

# %%
# %%time
inscription_number = 100
URL_form = "https://edh-www.adw.uni-heidelberg.de/data/api/inscriptions/search?"

response = requests.get(URL_form + "hd_nr=" + str(inscription_number))
response
json_data = response.json()
print(json_data)
# Out:
# {'limit': '20', 'total': 1, 'items': [{'last_update': '2015-05-21', 'transcription': 'D[---] / ANELI[---] / BERVE[---] / P[---]IT[------', 'work_status': 'provisional', 'diplomatic_text': 'D[ ] / ANELI[ ] / BERVE[ ] / P[ ]IT[', 'responsible_individual': 'Gräf', 'country': 'Spain', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000100', 'language': 'Latin', 'trismegistos_uri': 'https://www.trismegistos.org/text/226731', 'id': 'HD000100', 'findspot_modern': 'El Burgo de Osma', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/9371', 'literature': 'AE 1983, 0597.; C. García Merino, in: Homenaje al Prof. Martin Almagro Basch 3 (Madrid 1983) 355, Nr. 2; lám. 1, 2. - AE 1983.', 'findspot_ancient': 'Uxama', 'modern_region': 'Soria', 'commentary': ' Text in vier Zeilen, nahezu unlesbar.', 'province_label': 'Hispania citerior', 'type_of_monument': 'stele'}]}
# CPU times: user 13.6 ms, sys: 1.32 ms, total: 14.9 ms
# Wall time: 836 ms

# %%
def get_inscription_data(num):
  try:
    response = requests.get(URL_form + "hd_nr=" + str(num))
    json_data_items = response.json()["items"]
  except:
    time.sleep(1)
    try:
      response = requests.get(URL_form + "hd_nr=" + str(num))
      json_data_items = response.json()["items"]
    except:
      json_data_items = [{}]
  return json_data_items[0]

for num in range(1, 10):
  print(get_inscription_data(num))
# Out:
# {'depth': '2.7 cm', 'findspot_modern': 'Cuma, bei', 'width': '34 cm', 'diplomatic_text': 'D M / NONIAE P F OPTATAE / ET C IVLIO ARTEMONI / PARENTIBVS / LIBERTIS LIBERTABVSQVE / POSTERISQVE EORVM / C IVLIVS C F OPTATVS / FILIVS', 'material': 'Marmor, geädert / farbig', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/11843', 'modern_region': 'Campania', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000001', 'not_after': '0130', 'people': [{'cognomen': 'Optata', 'name': 'Noniae P.f. Optatae', 'person_id': '1', 'nomen': 'Nonia', 'gender': 'female'}, {'cognomen': 'Artemo', 'name': 'C. Iulio Artemoni', 'person_id': '2', 'praenomen': 'C.', 'nomen': 'Iulius', 'gender': 'male'}, {'nomen': 'Iulius', 'praenomen': 'C.', 'gender': 'male', 'cognomen': 'Optatus', 'name': 'C. Iulius C.f. Optatus', 'person_id': '3'}, {'name': 'Noniae P.f. Optatae', 'person_id': '4', 'cognomen': 'Optata', 'gender': 'female', 'nomen': 'Nonia'}, {'name': 'C. Iulio Artemoni', 'person_id': '5', 'cognomen': 'Artemo', 'gender': 'male', 'praenomen': 'C.', 'nomen': 'Iulius'}, {'person_id': '6', 'name': 'C. Iulius C.f. Optatus', 'cognomen': 'Optatus', 'gender': 'male', 'praenomen': 'C.', 'nomen': 'Iulius'}, {'person_id': '7', 'name': 'Noniae P.f. Optatae', 'cognomen': 'Optata', 'gender': 'female', 'nomen': 'Nonia'}, {'nomen': 'Iulius', 'praenomen': 'C.', 'gender': 'male', 'cognomen': 'Artemo', 'name': 'C. Iulio Artemoni', 'person_id': '8'}, {'gender': 'male', 'praenomen': 'C.', 'nomen': 'Iulius', 'person_id': '9', 'name': 'C. Iulius C.f. Optatus', 'cognomen': 'Optatus'}], 'country': 'Italy', 'id': 'HD000001', 'commentary': ' (C): 2. Hälfte 1. - Anfang 2. Jh. - AE; Ende 1. - 1. Hälfte 2. Jh. - Annecchino.', 'literature': 'AE 1983, 0192.; M. Annecchino, Puteoli 4/5, 1980/81, 286-287, Nr. 17; fig. 17. (C) - AE 1983.', 'trismegistos_uri': 'https://www.trismegistos.org/text/251193', 'work_status': 'provisional', 'not_before': '0071', 'letter_size': '3.2-2 cm', 'transcription': 'D(is) M(anibus) / Noniae P(ubli) f(iliae) Optatae / et C(aio) Iulio Artemoni / parentibus / libertis libertabusque / posterisque eorum / C(aius) Iulius C(ai) f(ilius) Optatus / filius', 'height': '33 cm', 'province_label': 'Latium et Campania (Regio I)', 'language': 'Latin', 'type_of_inscription': 'epitaph', 'type_of_monument': 'tabula', 'findspot_ancient': 'Cumae, bei', 'responsible_individual': 'Feraudi', 'last_update': '2014-04-07'}
# {'trismegistos_uri': 'https://www.trismegistos.org/text/265631', 'height': '28 cm', 'material': 'marble: rocks - metamorphic rocks', 'findspot': 'Via Nomentana, S. Alessandro, Kirche', 'modern_region': 'Lazio', 'country': 'Italy', 'type_of_inscription': 'epitaph', 'not_before': '0051', 'province_label': 'Roma', 'responsible_individual': 'Feraudi', 'letter_size': '4 cm', 'last_update': '2014-04-07', 'id': 'HD000002', 'language': 'Latin', 'work_status': 'no image', 'type_of_monument': 'tabula', 'people': [{'praenomen': 'C.', 'gender': 'male', 'name': 'C. Sextius Paris', 'cognomen': 'Paris', 'person_id': '1', 'age: years': '70', 'nomen': 'Sextius'}, {'cognomen': 'Paris', 'gender': 'male', 'name': 'C. Sextius Paris', 'praenomen': 'C.', 'nomen': 'Sextius', 'person_id': '2', 'age: years': '70'}, {'age: years': '70', 'person_id': '3', 'nomen': 'Sextius', 'gender': 'male', 'praenomen': 'C.', 'name': 'C. Sextius Paris', 'cognomen': 'Paris'}], 'not_after': '0200', 'literature': 'AE 1983, 0080. (A); A. Ferrua, RAL 36, 1981, 109, Nr. 7. - AE 1983.', 'commentary': ' AE 1983: Breite: 35 cm.', 'findspot_ancient': 'Roma', 'transcription': 'C(aius) Sextius Paris / qui vixit / annis LXX', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/19482', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000002', 'year_of_find': '1937', 'findspot_modern': 'Roma', 'diplomatic_text': 'C SEXTIVS PARIS / QVI VIXIT / ANNIS LXX', 'width': '85 cm'}
# {'not_before': '0131', 'province_label': 'Baetica', 'id': 'HD000003', 'people': [{'cognomen': 'Sisenna+ Rutilianus+', 'gender': 'male', 'praenomen': 'P.+', 'tribus': 'Galeria+', 'name': '[P. M]ummio [P.f. Gal. S]isenna[e Rutiliano]', 'status': 'senatorial order', 'person_id': '1', 'nomen': 'Mummius+'}, {'cognomen': 'Sisenna+ Rutilianus+', 'gender': 'male', 'praenomen': 'P.+', 'tribus': 'Galeria+', 'name': '[P. M]ummio [P.f. Gal. S]isenna[e Rutiliano]', 'person_id': '2', 'status': 'senatorial order', 'nomen': 'Mummius+'}, {'gender': 'male', 'cognomen': 'Sisenna+ Rutilianus+', 'praenomen': 'P.+', 'tribus': 'Galeria+', 'nomen': 'Mummius+', 'status': 'senatorial order', 'person_id': '3', 'name': '[P. M]ummio [P.f. Gal. S]isenna[e Rutiliano]'}], 'findspot_modern': 'Tomares', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000003', 'commentary': ' (B): [S]isenna ist falscher Kasus; folgende Ergänzung notwendig: [S]isenna[e]. Y: Text bezieht sich eher auf P. Mummius P.f. Sisenna Rutilianus (cos. suff. 146) als auf dessen Vater P. Mummius Sisenna (cos. ord. 133). Die Statuenbasis war in einem Gebäude vermauert.', 'last_update': '2006-08-31', 'material': 'marble: rocks - metamorphic rocks', 'country': 'Spain', 'responsible_individual': 'Feraudi', 'depth': '(12) cm', 'trismegistos_uri': 'https://www.trismegistos.org/text/220675', 'year_of_find': 'before 1975', 'work_status': 'provisional', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/2694', 'not_after': '0170', 'literature': 'AE 1983, 0518. (B); J. González, ZPE 52, 1983, 172-173; Taf. 5b. (B) - AE.', 'type_of_inscription': 'honorific inscription', 'language': 'Latin', 'width': '(34) cm', 'modern_region': 'Sevilla', 'transcription': '[P(ublio) M]ummio [P(ubli) f(ilio)] / [Gal(eria) S]isenna[e Ru]/[tiliano] Xv[ir(o) stli]/[tibus iudicandis ---] / [------', 'present_location': 'Sevilla, Privatbesitz', 'type_of_monument': 'statue base', 'letter_size': '4.5-3 cm', 'diplomatic_text': '[ ]VMMIO [ ] / [ ]ISENNA[ ] / [ ] XV[ ] / [ ] / [', 'height': '(37) cm'}
# {'not_after': '0200', 'language': 'Latin', 'transcription': '[---?]AV(?)S(?)[---]L(?)L(?)A / M(arci) Porci Nigri ser(va) / dominae Veneri / aram posuit', 'width': '27 cm', 'last_update': '2015-03-27', 'province_label': 'Baetica', 'not_before': '0151', 'religion': 'names of pagan deities', 'modern_region': 'Córdoba', 'country': 'Spain', 'trismegistos_uri': 'https://www.trismegistos.org/text/222102', 'present_location': 'Carcabuey, Grupo Escolar', 'type_of_inscription': 'votive inscription', 'external_image_uris': ['http://cil-old.bbaw.de/test06/bilder/datenbank/PH0005311.jpg'], 'height': '(39) cm', 'year_of_find': 'before 1979', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000004', 'id': 'HD000004', 'findspot_modern': 'Carcabuey', 'people': [{'name': '[---?]AV(?)S(?)[---]L(?)L(?)A M. Porci Nigri ser.', 'status': 'slaves', 'cognomen': '[---]', 'person_id': '1'}, {'praenomen': 'M.', 'name': 'M. Porci Nigri', 'person_id': '2', 'nomen': 'Porcius', 'cognomen': 'Niger'}, {'name': '[---?]AV(?)S(?)[---]L(?)L(?)A M. Porci Nigri ser.', 'status': 'slaves', 'cognomen': '[---]', 'person_id': '3'}, {'cognomen': 'Niger', 'nomen': 'Porcius', 'person_id': '4', 'name': 'M. Porci Nigri', 'praenomen': 'M.'}, {'name': '[---?]AV(?)S(?)[---]L(?)L(?)A M. Porci Nigri ser.', 'status': 'slaves', 'person_id': '5', 'cognomen': '[---]'}, {'cognomen': 'Niger', 'nomen': 'Porcius', 'person_id': '6', 'name': 'M. Porci Nigri', 'praenomen': 'M.'}], 'depth': '18 cm', 'material': 'limestone: rocks - clastic sediments', 'work_status': 'checked with photo', 'type_of_monument': 'altar', 'literature': 'AE 1983, 0533. (B); A.U. Stylow, Gerión 1, 1983, 267-273, Nr. 1; fig. 1. - AE 1983.; CIL 02, 01638. (B); CIL 02 (2. Aufl.) 05, 00274; Foto.', 'letter_size': '2.5 cm', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/2240', 'findspot_ancient': 'Ipolcobulcula', 'commentary': ' Material: lokaler grauer Kalkstein. (B): Stylow, AE 1983: Z. 1: A[---]L(?)L(?)A; CIL II 1638: Z. 1: Aemilia; Z. 2: Mar[--] Iponubensis(?); Z. 3: Veneris.', 'responsible_individual': 'Gräf', 'diplomatic_text': '[ ]AVS[ ]LLA / M PORCI NIGRI SER / DOMINAE VENERI / ARAM POSVIT'}
# {'commentary': ' (B): Z. 3: C(ai) l(ibertae) Tyches.', 'modern_region': 'Lazio', 'diplomatic_text': '[ ] L SVCCESSVS / [ ] L L IRENAEVS / [ ] C L TYCHES / [ ]VNT / [ ]RENTI F', 'type_of_monument': 'stele', 'language': 'Latin', 'literature': 'AE 1983, 0078. (B); A. Ferrua, RAL 36, 1981, 108, Nr. 3. - AE 1983.', 'id': 'HD000005', 'people': [{'praenomen': '[-]', 'cognomen': 'Successus', 'name': '[---]l. Successus', 'person_id': '1', 'status': 'freedmen / freedwomen', 'nomen': '[---]', 'gender': 'male'}, {'name': '[---] L.l. Irenaeus', 'person_id': '2', 'cognomen': 'Irenaeus', 'praenomen': '[-]', 'nomen': '[---]', 'status': 'freedmen / freedwomen', 'gender': 'male'}, {'gender': 'female', 'status': 'freedmen / freedwomen', 'nomen': '[---]', 'cognomen': 'Tyche', 'person_id': '3', 'name': '[---] C.l. Tyches(!)'}, {'status': 'freedmen / freedwomen', 'gender': 'male', 'nomen': '[---]', 'praenomen': '[-]', 'cognomen': 'Successus', 'person_id': '4', 'name': '[---]l. Successus'}, {'cognomen': 'Irenaeus', 'praenomen': '[-]', 'name': '[---] L.l. Irenaeus', 'person_id': '5', 'status': 'freedmen / freedwomen', 'nomen': '[---]', 'gender': 'male'}, {'cognomen': 'Tyche', 'person_id': '6', 'name': '[---] C.l. Tyches(!)', 'nomen': '[---]', 'status': 'freedmen / freedwomen', 'gender': 'female'}, {'status': 'freedmen / freedwomen', 'gender': 'male', 'nomen': '[---]', 'cognomen': 'Successus', 'praenomen': '[-]', 'name': '[---]l. Successus', 'person_id': '7'}, {'gender': 'male', 'status': 'freedmen / freedwomen', 'nomen': '[---]', 'praenomen': '[-]', 'cognomen': 'Irenaeus', 'person_id': '8', 'name': '[---] L.l. Irenaeus'}, {'cognomen': 'Tyche', 'name': '[---] C.l. Tyches(!)', 'person_id': '9', 'status': 'freedmen / freedwomen', 'nomen': '[---]', 'gender': 'female'}], 'work_status': 'no image', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000005', 'country': 'Italy', 'trismegistos_uri': 'https://www.trismegistos.org/text/265629', 'not_after': '0200', 'findspot_ancient': 'Roma', 'last_update': '2010-01-04', 'province_label': 'Roma', 'type_of_inscription': 'epitaph', 'transcription': '[---] l(ibertus) Successus / [---] L(uci) l(ibertus) Irenaeus / [---] C(ai) l(iberta) Tyches(!) / [---]unt / [--- me]renti f(---)', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/19428', 'not_before': '0001', 'findspot_modern': 'Roma', 'findspot': 'Via Cupa (ehem. Vigna Nardi)', 'responsible_individual': 'Feraudi'}
# {'not_before': '0071', 'material': 'limestone: rocks - clastic sediments', 'findspot_modern': 'Cañete la Real', 'people': [{'cognomen': 'Auctina+', 'person_id': '1', 'gender': 'female', 'age: years': '70', 'nomen': 'Memmia', 'name': 'Memmia Auctin[a]'}, {'person_id': '2', 'cognomen': 'Auctina+', 'name': 'Memmia Auctin[a]', 'gender': 'female', 'nomen': 'Memmia', 'age: years': '70'}, {'person_id': '3', 'cognomen': 'Auctina+', 'name': 'Memmia Auctin[a]', 'gender': 'female', 'age: years': '70', 'nomen': 'Memmia'}], 'findspot': 'Huerta Nueva', 'language': 'Latin', 'letter_size': '7-4 cm', 'height': '145 cm', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000006', 'diplomatic_text': 'D M S / / MEMMIA AVCTIN[ ] / AN LXX PIA IN SVIS / H S E S T TE[ ] L', 'province_label': 'Baetica', 'literature': 'AE 1983, 0524. (B); P. Rodríguez Oliva - R. Atencia Páez, BSEAA 49, 1983, 154, Nr. 3; lám. 3,2. (B) - AE 1983.; CIL 02 (2. Aufl.) 05, 00883.', 'transcription': 'D(is) M(anibus) s(acrum) // Memmia Auctin[a] / an(norum) LXX pia in suis / h(ic) s(ita) e(st) s(it) t(ibi) te[r(ra)] l(evis)', 'type_of_inscription': 'epitaph', 'modern_region': 'Málaga', 'id': 'HD000006', 'work_status': 'checked with photo', 'not_after': '0150', 'year_of_find': '1974', 'responsible_individual': 'Gräf', 'country': 'Spain', 'present_location': 'Cañete la Real', 'depth': '15 cm', 'type_of_monument': 'stele', 'trismegistos_uri': 'https://www.trismegistos.org/text/222924', 'width': '60 cm', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/2999', 'findspot_ancient': 'Sabora, bei', 'commentary': ' Der Stein ist aus 2 aneinanderpassenden Fragmenten zusammengesetzt. Z. 1 befindet sich oberhalb des gerahmten Inschriftfeldes. (B): Rodríguez Oliva - Atencia, AE 1983: Z. 4: t(erra).', 'last_update': '2011-06-10'}
# {'people': [{'gender': 'female', 'person_id': '1', 'name': 'Clodia M.f.', 'nomen': 'Clodia'}, {'nomen': 'Clodia', 'person_id': '2', 'name': 'Clodia M.f.', 'gender': 'female'}, {'nomen': 'Clodia', 'name': 'Clodia M.f.', 'person_id': '3', 'gender': 'female'}], 'id': 'HD000007', 'width': '53 cm', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/19483', 'findspot': 'Via Nomentana, Tor Lupara', 'commentary': ' (C): Datierung: Zeit Sullas.', 'province_label': 'Roma', 'transcription': 'Clodia M(arci) f(ilia)', 'not_after': '-0051', 'type_of_inscription': 'epitaph', 'responsible_individual': 'Feraudi', 'last_update': '2010-01-04', 'not_before': '-0100', 'trismegistos_uri': 'https://www.trismegistos.org/text/265588', 'language': 'Latin', 'modern_region': 'Lazio', 'findspot_ancient': 'Roma', 'work_status': 'checked with photo', 'diplomatic_text': 'CLODIA M F', 'present_location': 'Mentana, Privatbesitz', 'country': 'Italy', 'findspot_modern': 'Roma', 'type_of_monument': 'tabula', 'material': 'travertine: rocks - chemische Sedimente', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000007', 'letter_size': '9 cm', 'literature': 'AE 1983, 0033. (C); G. Pisani Sartorio, in: G. Barbieri (Hrsg.), Il lapidario Zeri di Mentana (Roma 1982) 3-4, Nr. 2; tav. 2,1. - AE 1983.', 'height': '35 cm'}
# {'last_update': '2013-12-03', 'commentary': ' Tafel aus mehreren anpassenden Fragmenten zusammengesetzt. Vermutlich stadtrömische Inschrift.', 'work_status': 'provisional', 'transcription': 'D(is) M(anibus) / C(aio) Satrio Xantho / C(ai) Satri Rufi lib(erto) / decuriali lictorio / Satria Nymphidia marito / optimo et fidelissimo et sibi et / libertis libertabusq(ue) suis / posterisq(ue) eorum fecit', 'diplomatic_text': 'D M / C SATRIO XANTHO / C SATRI RVFI LIB / DECVRIALI LICTORIO / SATRIA NYMPHIDIA MARITO / OPTIMO ET FIDELISSIMO ET SIBI ET / LIBERTIS LIBERTABVSQ SVIS / POSTERISQ EORVM FECIT', 'people': [{'gender': 'male', 'cognomen': 'Xanthus', 'praenomen': 'C.', 'person_id': '1', 'occupation': 'data available', 'status': 'freedmen / freedwomen', 'nomen': 'Satrius', 'name': 'C. Satrio Xantho C. Satri Rufi lib.'}, {'praenomen': 'C.', 'person_id': '2', 'cognomen': 'Rufus', 'gender': 'male', 'nomen': 'Satrius', 'name': 'C. Satri Rufi'}, {'name': 'Satria Nymphidia', 'status': 'freedmen / freedwomen?', 'nomen': 'Satria', 'gender': 'female', 'cognomen': 'Nymphidia', 'person_id': '3'}, {'nomen': 'Satrius', 'status': 'freedmen / freedwomen', 'occupation': 'data available', 'praenomen': 'C.', 'person_id': '4', 'gender': 'male', 'cognomen': 'Xanthus', 'name': 'C. Satrio Xantho C. Satri Rufi lib.'}, {'nomen': 'Satrius', 'name': 'C. Satri Rufi', 'praenomen': 'C.', 'person_id': '5', 'gender': 'male', 'cognomen': 'Rufus'}, {'name': 'Satria Nymphidia', 'status': 'freedmen / freedwomen?', 'nomen': 'Satria', 'gender': 'female', 'cognomen': 'Nymphidia', 'person_id': '6'}, {'name': 'C. Satrio Xantho C. Satri Rufi lib.', 'nomen': 'Satrius', 'occupation': 'data available', 'status': 'freedmen / freedwomen', 'praenomen': 'C.', 'person_id': '7', 'gender': 'male', 'cognomen': 'Xanthus'}, {'name': 'C. Satri Rufi', 'nomen': 'Satrius', 'cognomen': 'Rufus', 'gender': 'male', 'person_id': '8', 'praenomen': 'C.'}, {'nomen': 'Satria', 'status': 'freedmen / freedwomen?', 'name': 'Satria Nymphidia', 'person_id': '9', 'gender': 'female', 'cognomen': 'Nymphidia'}], 'responsible_individual': 'Feraudi', 'fotos': ['https://edh-www.adw.uni-heidelberg.de/fotos/F023291.JPG', 'https://edh-www.adw.uni-heidelberg.de/fotos/F029577.JPG'], 'modern_region': 'Lazio?', 'literature': 'AE 1983, 0060.; R. Palmieri, in: G. Barbieri (Hrsg.), Il lapidario Zeri di Mentana (Roma 1982) 109-110, Nr. 48; tav. 44, 1. - AE 1983.', 'country': 'Italy', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/19664', 'type_of_inscription': 'epitaph', 'type_of_monument': 'tabula', 'letter_size': '4-2 cm', 'present_location': 'Mentana, Privatbesitz', 'findspot_modern': 'Roma?', 'height': '52 cm', 'width': '65 cm', 'province_label': 'Roma?', 'findspot_ancient': 'Roma?', 'language': 'Latin', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000008', 'id': 'HD000008', 'not_before': '0101', 'material': 'marble: rocks - metamorphic rocks', 'not_after': '0200', 'trismegistos_uri': 'https://www.trismegistos.org/text/265611'}
# {'transcription': 'ABCDEFX', 'religion': 'magic/spells', 'commentary': ' Material: Blei-Zinn-Kupfer-Legierung. Vielleicht zu verstehen als ABC def(i)x(io).', 'diplomatic_text': 'ABCDEFX', 'edh_geography_uri': 'https://edh-www.adw.uni-heidelberg.de/edh/geographie/4502', 'language': 'Latin', 'width': '6.5 cm', 'height': '5.2 cm', 'last_update': '2019-03-29', 'work_status': 'checked with drawing', 'material': 'Blei, Zinn', 'country': 'United Kingdom', 'literature': 'AE 1983, 0632.; M.W.C. Hassall - R.S.O. Tomlin, Britannia 14, 1983, 336, Nr. 2; fig. 32 (Zeichnung). - AE 1983.; R.S.O. Tomlin, in: B. Cunliffe (Hrsg.), The Temple of Sulis Minerva at Bath.; Volume 2 The Finds from the Sacred Spring.; (Oxford 1988) 108, Nr. 1; Zeichnung.; A. Kropp, Defixiones. Ein aktuelles Corpus lateinischer Fluchtafeln (Speyer 2008) Nr. 3.2/3.', 'responsible_individual': 'Cowey', 'year_of_find': '1979', 'province_label': 'Britannia', 'modern_region': 'Somerset', 'not_before': '0201', 'findspot_ancient': 'Aquae Sulis', 'id': 'HD000009', 'findspot': 'Römisches Bad, Sacred Spring', 'uri': 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000009', 'type_of_monument': 'tessera', 'findspot_modern': 'Bath', 'present_location': 'Bath, Roman Baths Mus.', 'not_after': '0300', 'trismegistos_uri': 'https://www.trismegistos.org/text/168722', 'type_of_inscription': 'defixio'}

# %%
### the actual data are part of the tag "items"
# %%time 
pd.DataFrame(json_data["items"])
# Out:
# CPU times: user 2.87 ms, sys: 0 ns, total: 2.87 ms
# Wall time: 2.82 ms
#   findspot_ancient   findspot_modern  ... responsible_individual country
# 0            Uxama  El Burgo de Osma  ...                   Gräf   Spain
#
# [1 rows x 18 columns]

# %% [markdown]
# # Inscriptions one by one (using simple paralel computing)

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
#### TEST without paralel computing:

# %%time
all_inscriptions = []
for num in range(1,200): 
  currently_parsed = get_inscription_data(num)
  all_inscriptions.extend(currently_parsed)
# Out:
# CPU times: user 2.23 s, sys: 113 ms, total: 2.34 s
# Wall time: 2min 48s

# %%
### TEST with paralel computing
###to make N requests in paralel, we first have to generate a range of ranges: [1,2,3], [4,5,6], [7,8,9]
# %%time
all_inscriptions = []
for num in range(1,200, 100): 
  actual_nums = list(range(num, num+100))
  with ThreadPoolExecutor(max_workers=100) as pool:
    currently_parsed = list(pool.map(get_inscription_data,actual_nums))
  all_inscriptions.extend(currently_parsed)
# Out:
# CPU times: user 3.76 s, sys: 257 ms, total: 4.02 s
# Wall time: 13.2 s

# %% [markdown]
# ok, the testing clearly demonstrate that using 100 workers in paralel is about 10 times faster. Let's scale it up for the whole dataset

# %%
### main run of the function

# %%time
all_inscriptions = []
for num in range(1,90000, 200): 
  actual_nums = list(range(num, num+200))
  with ThreadPoolExecutor(max_workers=300) as pool:
    currently_parsed = list(pool.map(get_inscription_data,actual_nums))
  all_inscriptions.extend(currently_parsed)
# Out:
# CPU times: user 32min 3s, sys: 2min 34s, total: 34min 38s
# Wall time: 1h 50min 50s

# %%
inscriptions_data_df = pd.DataFrame(all_inscriptions)

# %%
s.put(sddk_url + "SDAM_data/EDH/EDH_onebyone.json", data=inscriptions_data_df.to_json())
# Out:
# <Response [204]>
